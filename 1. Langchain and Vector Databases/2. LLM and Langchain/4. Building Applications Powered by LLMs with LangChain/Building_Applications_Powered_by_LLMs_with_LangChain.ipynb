# %%
from IPython.display import clear_output

# %%
# %pip install langchain_mistralai llama-cpp-python langchain deeplake tiktoken pypdf langchain_community langchain_huggingface -q
clear_output()
# %pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# accelerate                       0.32.1
# aioboto3                         13.1.1
# aiobotocore                      2.13.1
# aiofiles                         24.1.0
# aiohappyeyeballs                 2.4.0
# aiohttp                          3.10.5
# aioitertools                     0.11.0
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albucore                         0.0.13
# albumentations                   1.4.14
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.18.0
# asn1crypto                       1.5.1
# astropy                          6.1.2
# ...

# %%
import os
from google.colab import userdata
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = userdata.get('LANGCHAIN_API_KEY')
os.environ["MISTRAL_API_KEY"] = userdata.get('MISTRAL_API')
os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get('HF_TOKEN')
os.environ["ACTIVELOOP_TOKEN"] = userdata.get('ACTIVELOOP_API')
# os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_KEY')
# os.environ["GOOGLE_CSE_ID"] = userdata.get('GOOGLE_CSE_ID')

# %%
# !wget https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF/resolve/main/llama-2-7b-chat.Q4_K_M.gguf
# Out:
# --2024-08-25 15:27:39--  https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF/resolve/main/llama-2-7b-chat.Q4_K_M.gguf
# Resolving huggingface.co (huggingface.co)... 3.163.189.114, 3.163.189.74, 3.163.189.90, ...
# Connecting to huggingface.co (huggingface.co)|3.163.189.114|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from langchain_community.llms import LlamaCpp

chat = LlamaCpp(
    model_path = '/content/llama-2-7b-chat.Q4_K_M.gguf',
    temperature = 0,
    max_tokens=512,
    model_kwargs = {
          'stop_sequences':["\n", "\n\n"],
    }
)
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from /content/llama-2-7b-chat.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 11008
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %%
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate
)


template = "You are an assistant that helps users find information about movies."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)

human_template = "Find information about the movie {movie_title}."
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# %%
chat_input = chat_prompt.format_prompt(movie_title="Inception").to_messages()
response = chat.invoke(chat_input)
# Out:
# Llama.generate: 27 prefix-match hit, remaining 1 prompt tokens to eval
#
# llama_print_timings:        load time =    4734.67 ms
# llama_print_timings:      sample time =     129.05 ms /   176 runs   (    0.73 ms per token,  1363.84 tokens per second)
# llama_print_timings: prompt eval time =       0.00 ms /     0 tokens (    -nan ms per token,     -nan tokens per second)
# llama_print_timings:        eval time =  119225.72 ms /   176 runs   (  677.42 ms per token,     1.48 tokens per second)
# llama_print_timings:       total time =  119576.73 ms /   176 tokens

# %%
response
# Out:
# "\nAssistant: Of course! Inception is a 2010 science fiction action film written, co-produced, and directed by Christopher Nolan. The movie follows Cobb (Leonardo DiCaprio), a skilled thief who specializes in entering people's dreams and stealing their secrets. Cobb is offered a chance to redeem himself by performing an impossible task: planting an idea in someone's mind instead of stealing one. The movie explores the concept of shared dreaming and features a talented cast, including Joseph Gordon-Levitt, Ellen Page, and Tom Hardy. Inception was well received by critics and audiences alike, and it has become one of Nolan's most popular films. Is there anything else you would like to know about Inception?"

# %%
# !wget https://www.cheat-sheets.org/saved-copy/The%20One%20Page%20Linux%20Manual.pdf
# Out:
# --2024-08-25 15:55:48--  https://www.cheat-sheets.org/saved-copy/The%20One%20Page%20Linux%20Manual.pdf
# Resolving www.cheat-sheets.org (www.cheat-sheets.org)... 90.156.201.79, 90.156.201.114, 90.156.201.28, ...
# Connecting to www.cheat-sheets.org (www.cheat-sheets.org)|90.156.201.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96538 (94K) [application/pdf]
# Saving to: ‘The One Page Linux Manual.pdf’
#
# The One Page Linux  100%[===================>]  94.28K   183KB/s    in 0.5s
#
# 2024-08-25 15:55:49 (183 KB/s) - ‘The One Page Linux Manual.pdf’ saved [96538/96538]

# %%
# !wget https://huggingface.co/microsoft/Phi-3-mini-4k-instruct-gguf/resolve/main/Phi-3-mini-4k-instruct-q4.gguf

# %%
from langchain.document_loaders import PyPDFLoader

document_loader = PyPDFLoader(file_path = '/content/linux.pdf')
document = document_loader.load()

# %%
from langchain.chains.summarize.chain import load_summarize_chain
from langchain_mistralai import ChatMistralAI

# Small context window. gotta send in chunks or a truncated document with this model
# llm = LlamaCpp(
#     model_path = '/content/Phi-3-mini-4k-instruct-q4.gguf',
#     temperature = 0,
#     max_tokens=3000,
#     model_kwargs = {
#           'stop_sequences':["\n", "\n\n"],
#     }
# )

llm = ChatMistralAI(
    temperature=0
)

summarize_chain = load_summarize_chain(llm)

# %%
summary = summarize_chain.run(document)
print(summary)
# Out:
# This is a one-page manual of useful Linux commands, version 3.0 from May 1999. It covers various topics including starting and stopping the system, accessing and mounting file systems, finding files and text within files, the X Window System, moving, copying, deleting & viewing files, installing software for Linux, user administration, little known tips and tricks, configuration files and what they do, file permissions, X shortcuts, and printing.
#
# The manual provides commands for shutting down and rebooting the system, mounting and unmounting file systems with different formats, finding files using the "find" and "locate" commands, configuring the X Window System using different utilities, copying, moving, and deleting files, installing and upgrading software using RPM, managing users, and formatting floppy disks.
#
# ...

# %%
from langchain.prompts import PromptTemplate

llm = LlamaCpp(
    model_path = '/content/Phi-3-mini-4k-instruct-q4.gguf',
    temperature = 0,
    max_tokens=3000,
    model_kwargs = {
          'stop_sequences':["\n", "\n\n"],
    }
)

prompt = PromptTemplate(
    template="Question: {question}\nAnswer:",
    input_variables=["question"]
    )

chain = prompt | llm
# Out:
# llama_model_loader: loaded meta data with 24 key-value pairs and 195 tensors from /content/Phi-3-mini-4k-instruct-q4.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = phi3
# llama_model_loader: - kv   1:                               general.name str              = Phi3
# llama_model_loader: - kv   2:                        phi3.context_length u32              = 4096
# llama_model_loader: - kv   3:                      phi3.embedding_length u32              = 3072
# llama_model_loader: - kv   4:                   phi3.feed_forward_length u32              = 8192
# llama_model_loader: - kv   5:                           phi3.block_count u32              = 32
# llama_model_loader: - kv   6:                  phi3.attention.head_count u32              = 32
# ...

# %%
chain.invoke({
    'question': 'What is the meaning of life?'
})
# Out:
# llama_print_timings:        load time =    1902.60 ms
# llama_print_timings:      sample time =     348.62 ms /   499 runs   (    0.70 ms per token,  1431.37 tokens per second)
# llama_print_timings: prompt eval time =    3022.88 ms /    13 tokens (  232.53 ms per token,     4.30 tokens per second)
# llama_print_timings:        eval time =  205062.76 ms /   498 runs   (  411.77 ms per token,     2.43 tokens per second)
# llama_print_timings:       total time =  209301.45 ms /   511 tokens
# ...
